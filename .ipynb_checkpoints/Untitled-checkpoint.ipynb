# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib widget

# %%
'''# plt.figure()
# plt.plot(np.arange(5))'''
# Out:
# '# plt.figure()\n# plt.plot(np.arange(5))'

# %%
data = pd.read_csv('data_uk_2.csv', skiprows=4)
data.dropna(inplace=True)

# %%
data.head()
# Out:
#            Period\Unit: [UK pound sterling ]
# 2023-09-01      0.85538     Normal value (A)
# 2023-08-31      0.85718     Normal value (A)
# 2023-08-30      0.85920     Normal value (A)
# 2023-08-29      0.85860     Normal value (A)
# 2023-08-28      0.85815     Normal value (A)

# %%
dat = data['Period\\Unit:'].to_numpy()
dat[dat == '-'] = np.nan
dat = np.float64(dat)
data['Period\\Unit:'] = dat
data.dropna(inplace=True)
data['date'] = data.index
data.plot(x='date', y=['Period\\Unit:'])
# Out:
# <Axes: xlabel='date'>
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
from datetime import datetime
date = pd.to_datetime(data['date'])
data['date'] = date
data.head()

data = data.drop(columns= ['index'])

# %%
data.plot()

data_price = data['Period\\Unit:'].to_numpy()
max_val = np.max(data_price)
max_idx = np.argmax(data_price)
min_val = np.min(data_price)
min_idx = np.argmin(data_price)

print(f"Max val of {max_val:.3f} at date {data['date'].iloc[max_idx]}")
print(f"Min val of {min_val:.3f} at date {data['date'].iloc[min_idx]}")

plt.axhline(max_val, linestyle='dotted')
plt.axhline(min_val, linestyle='dotted')
# Out:
# Max val of 0.979 at date 2008-12-29 00:00:00
# Min val of 0.571 at date 2000-05-03 00:00:00
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
data['diff'] = data['Period\\Unit:'].diff(-1)
data.plot(y=['diff'])
# Out:
# <Axes: >
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
data[data.columns[::-1]]
# Out:
#          diff        date [UK pound sterling ]  Period\Unit:       index  \
# 0    -0.00180  2023-09-01     Normal value (A)       0.85538  2023-09-01
# 1    -0.00202  2023-08-31     Normal value (A)       0.85718  2023-08-31
# 2     0.00060  2023-08-30     Normal value (A)       0.85920  2023-08-30
# 3     0.00045  2023-08-29     Normal value (A)       0.85860  2023-08-29
# 4     0.00172  2023-08-28     Normal value (A)       0.85815  2023-08-28
# ...       ...         ...                  ...           ...         ...
# 6314  0.00355  1999-01-08     Normal value (A)       0.70940  1999-01-08
# 6315 -0.00175  1999-01-07     Normal value (A)       0.70585  1999-01-07
# 6316 -0.00460  1999-01-06     Normal value (A)       0.70760  1999-01-06
# 6317  0.00110  1999-01-05     Normal value (A)       0.71220  1999-01-05
# 6318      NaN  1999-01-04     Normal value (A)       0.71110  1999-01-04
#
#       level_0
# 0           0
# 1           1
# 2           2
# 3           3
# 4           4
# ...       ...
# 6314     6314
# 6315     6315
# 6316     6316
# 6317     6317
# 6318     6318
#
# [6319 rows x 6 columns]

# %%
data.head()
# Out:
#    Period\Unit: [UK pound sterling ]       date     diff
# 0       0.85538     Normal value (A) 2023-09-01 -0.00180
# 1       0.85718     Normal value (A) 2023-08-31 -0.00202
# 2       0.85920     Normal value (A) 2023-08-30  0.00060
# 3       0.85860     Normal value (A) 2023-08-29  0.00045
# 4       0.85815     Normal value (A) 2023-08-28  0.00172

# %%
for cols in data.columns:
    print (cols)
# Out:
# level_0
# index
# Period\Unit:
# [UK pound sterling ]
# date
# diff

# %%
data_new = data.iloc[::-1]
data_new.head()
# Out:
#       Period\Unit: [UK pound sterling ]       date     diff
# 6318       0.71110     Normal value (A) 1999-01-04      NaN
# 6317       0.71220     Normal value (A) 1999-01-05  0.00110
# 6316       0.70760     Normal value (A) 1999-01-06 -0.00460
# 6315       0.70585     Normal value (A) 1999-01-07 -0.00175
# 6314       0.70940     Normal value (A) 1999-01-08  0.00355

# %%
data.dropna(inplace = True)

# %%
data.plot(x= 'date', y = ['diff'])
# Out:
# <Axes: xlabel='date'>
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
max_diff = np.max(data['diff'])
max_diff_idx = np.argmax(data['diff'])
type(data['date'].loc[max_diff_idx])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
from datetime import date
data.loc[data['date'] =='2018-08-29 00:00:00'].index.values
# Out:
# array([1285], dtype=int64)

# %%
data['date'].loc[3]
# Out:
# Timestamp('2023-08-29 00:00:00')

# %%
datetime(2018,9,1,0,0,0)
# Out:
# datetime.datetime(2018, 9, 1, 0, 0)

# %%
data_new_3 = data[:1286]
data_new_3.plot(x= 'date', y = ['diff'])
# Out:
# <Axes: xlabel='date'>
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
