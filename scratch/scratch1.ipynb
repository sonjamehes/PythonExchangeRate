# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib widget
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[98], line 3
#       1 import pandas as pd
#       2 import matplotlib.pyplot as plt
# ----> 3 get_ipython().run_line_magic('matplotlib', 'widget')
#
# File c:\Users\SonjaMehes\Documents\PythonExchangeRate\venv\Lib\site-packages\IPython\core\interactiveshell.py:2432, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2430     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2431 with self.builtin_trap:
# -> 2432     result = fn(*args, **kwargs)
#    2434 # The code below prevents the output from being displayed
#    2435 # when using magics with decorator @output_can_be_silenced
#    2436 # when the last Python token in the expression is a ';'.
#    2437 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# ...

# %%
file_path_csv = 'C:\\Users\\SonjaMehes\\Documents\\PythonExchangeRate\\data.csv'
file_path_excel = 'C:\\Users\\SonjaMehes\\Documents\\PythonExchangeRate\\data2.xlsx'
file_path_allrates = 'C:\\Users\\SonjaMehes\\Documents\\PythonExchangeRate\\PythonExchange.xlsx'

# %%
df = pd.read_csv(file_path_csv)

# %%
print(df.head())
# Out:
#   Period\Unit:  [Danish krone ]
# 0   2023-09-01           7.4528
# 1   2023-08-31           7.4523
# 2   2023-08-30           7.4531
# 3   2023-08-29           7.4529
# 4   2023-08-28           7.4530

# %%
# Convert 'Period\\Unit:' column to datetime
df['Period\\Unit:'] = pd.to_datetime(df['Period\\Unit:'])

# Simple plot
df.plot(x='Period\\Unit:', y='[Danish krone ]', title='Danish Krone against Euro')
plt.show()

# %%
df2 = pd.read_excel(file_path_excel, engine='openpyxl', skiprows=3)
print(df2)
# Out:
#               Collection: Average of observations through period (A)
# 0            Period\Unit:                            [Danish krone ]
# 1     2023-09-01 00:00:00                                     7.4528
# 2     2023-08-31 00:00:00                                     7.4523
# 3     2023-08-30 00:00:00                                     7.4531
# 4     2023-08-29 00:00:00                                     7.4529
# ...                   ...                                        ...
# 1268  2018-09-24 00:00:00                                     7.4597
# 1269  2018-09-21 00:00:00                                     7.4597
# 1270  2018-09-20 00:00:00                                     7.4592
# 1271  2018-09-19 00:00:00                                     7.4597
# 1272  2018-09-18 00:00:00                                     7.4602
#
# [1273 rows x 2 columns]

# %%
df3 = pd.read_excel(file_path_allrates, skiprows=2, usecols='B:AVC')
print(df3)
# Out:
#   Currency  2018M08D01  2018M08D02  2018M08D03  2018M08D06  2018M08D07  \
# 0      EUR    745.1400    745.1500    745.2600    745.2000    745.2000
# 1      USD    637.0900    641.4300    643.1300    645.5900    642.3000
# 2      GBP    836.8600    835.8900    836.9000    834.6800    832.7800
# 3      JPY      5.6964      5.7572      5.7638      5.7911      5.7821
#
#    2018M08D08  2018M08D09  2018M08D10  2018M08D13  ...  2023M07D18  \
# 0    745.3400    745.6600    745.4400    745.3600  ...    745.0900
# 1    643.1400    643.2000    650.7000    653.6500  ...    662.0100
# 2    827.3700    829.0600    831.2700    834.3900  ...    868.0200
# 3      5.7904      5.7875      5.8664      5.9104  ...      4.7947
#
#    2023M07D19  2023M07D20  2023M07D21  2023M07D24  2023M07D25  2023M07D26  \
# 0    745.0700    745.0800    745.0800    745.1400    745.1500    745.1700
# 1    663.9400    665.4300    669.8600    671.5400    674.2800    673.8100
# ...

# %%
# file_path_csv = 'C:\\Users\\SonjaMehes\\Documents\\PythonExchangeRate\\data.csv'
df = pd.read_csv("data_uk.csv", skiprows=4)
df.head()
# Out:
#   Period\Unit: [UK pound sterling ]
# 0   2023-09-01              0.85538
# 1   2023-08-31              0.85718
# 2   2023-08-30              0.85920
# 3   2023-08-29              0.85860
# 4   2023-08-28              0.85815

# %%
df.plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 df.plot()
#
# File c:\Users\SonjaMehes\Documents\PythonExchangeRate\venv\Lib\site-packages\pandas\plotting\_core.py:1031, in PlotAccessor.__call__(self, *args, **kwargs)
#    1028             label_name = label_kw or data.columns
#    1029             data.columns = label_name
# -> 1031 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File c:\Users\SonjaMehes\Documents\PythonExchangeRate\venv\Lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# ...

# %%
df['Time']=df['Period\\Unit:']
df['Price']=df['[UK pound sterling ]']

# %%
import numpy as np
price = df['Price'].to_numpy()

for i in range(len(price)):
    price[i] = float(price[i])

'''plt.figure()
plt.plot(price)
plt.show()'''

price
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[106], line 5
#       2 price = df['Price'].to_numpy()
#       4 for i in range(len(price)):
# ----> 5     price[i] = float(price[i])
#       7 '''plt.figure()
#       8 plt.plot(price)
#       9 plt.show()'''
#      11 price
#
# ValueError: could not convert string to float: '-'

# %%
data_uk = pd.read_csv('data_uk_2.csv', skiprows=4)
data_uk.dropna(inplace=True)
data_uk.head()
# Out:
#            Period\Unit: [UK pound sterling ]
# 2023-09-01      0.85538     Normal value (A)
# 2023-08-31      0.85718     Normal value (A)
# 2023-08-30      0.85920     Normal value (A)
# 2023-08-29      0.85860     Normal value (A)
# 2023-08-28      0.85815     Normal value (A)

# %%
#data_uk['Period\\Unit:'] = data_uk['Period\\Unit:'].astype(float)

data_test = data_uk['Period\\Unit:'].to_numpy()

idx = np.where(data_test == '-')
idx = idx[0]
idx
# Out:
# array([], dtype=int64)

# %%
data_test[data_test == '-'] = np.nan

# %%
data_uk['Period\\Unit:'].shape
# Out:
# (6319,)

# %%
data_uk['Period\\Unit:'] = data_test
data_uk.dropna(inplace=True)
data_uk.iloc[2903]
# Out:
# Period\Unit:                     0.81205
# [UK pound sterling ]    Normal value (A)
# diff                             -0.0009
# Name: 2012-05-02, dtype: object

# %%
data_uk['Period\\Unit:'] = data_uk['Period\\Unit:'].astype(float)

# %%
data_uk.plot()

data_price = data_uk['Period\\Unit:'].to_numpy()
max_val = np.max(data_price)
max_idx = np.argmax(data_price)
min_val = np.min(data_price)
min_idx = np.argmin(data_price)

print(f"Max val of {max_val:.3f} at date {max_idx}")
print(f"Min val of {min_val:.3f} at date {min_idx}")

plt.axhline(max_val, linestyle='dotted')
plt.axhline(min_val, linestyle='dotted')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 data_uk.plot()
#       3 data_price = data_uk['Period\\Unit:'].to_numpy()
#       4 max_val = np.max(data_price)
#
# NameError: name 'data_uk' is not defined

# %%
data_uk['diff'] = data_uk['Period\\Unit:'].diff(-1)
data_uk.plot(y=['diff'])
# Out:
# <Axes: >

# %%
data_uk['Period\\Unit:'].loc['2023-09-01']
# Out:
# 0.85538
